# %%
import pandas as pd
from datetime import datetime
import numpy as np

# %%
df = pd.read_csv("../data/simulated/simulated_buses_multi.csv", parse_dates=["timestamp"])

# %%
df

df['timestamp'] = df['timestamp'].dt.floor('s')
grouped = df.groupby('timestamp')

# %%
df['manual_timediff'] = (df['timestamp'] - datetime(2025, 1, 12, 9, 0, 0)).dt.total_seconds().astype(int)

# %%
df
# Out:
#                  timestamp  route_id  direction_id   latitude   longitude  \
# 0      2025-01-12 09:00:00    292028             1  49.266003 -123.247825
# 1      2025-01-12 09:01:10    292028             1  49.266138 -123.246883
# 2      2025-01-12 09:02:34    292028             1  49.266323 -123.245606
# 3      2025-01-12 09:03:46    292028             1  49.266351 -123.245407
# 4      2025-01-12 09:04:16    292028             1  49.266364 -123.245318
# ...                    ...       ...           ...        ...         ...
# 211195 2025-01-12 17:52:43    298165             0  49.266136 -123.245447
# 211196 2025-01-12 17:54:00    298165             0  49.266410 -123.245678
# 211197 2025-01-12 17:55:31    298165             0  49.267494 -123.246765
# 211198 2025-01-12 17:56:01    298165             0  49.267331 -123.247308
# 211199 2025-01-12 17:57:55    298165             0  49.266924 -123.248444
#
#                                       bus_id  elapsed_seconds  manual_timediff
# 0       636c2502-8780-46b5-8c5c-abfa8ae8a185                0                0
# 1       636c2502-8780-46b5-8c5c-abfa8ae8a185               70               70
# 2       636c2502-8780-46b5-8c5c-abfa8ae8a185              154              154
# 3       636c2502-8780-46b5-8c5c-abfa8ae8a185              226              226
# 4       636c2502-8780-46b5-8c5c-abfa8ae8a185              256              256
# ...                                      ...              ...              ...
# 211195  ad839414-3772-4acc-aeb4-50008edc2d19             9704            31963
# 211196  ad839414-3772-4acc-aeb4-50008edc2d19             9781            32040
# 211197  ad839414-3772-4acc-aeb4-50008edc2d19             9871            32131
# 211198  ad839414-3772-4acc-aeb4-50008edc2d19             9901            32161
# 211199  ad839414-3772-4acc-aeb4-50008edc2d19            10016            32275
#
# [211200 rows x 8 columns]

# %%
grouped_timediff = list(df['manual_timediff'].unique())

# %%
grouped_timediff.sort()

# %%
len(grouped_timediff)
# Out:
# 31025

# %%
len(np.diff(grouped_timediff))
# Out:
# 31024

# %%
import asyncio
import websockets
import json
from datetime import datetime

async def connect_to_websocket(speed_multiplier: float = 2.0):
    # Connect to the WebSocket server with speed multiplier
    uri = f"ws://localhost:8000/ws/simulated?speed_multiplier={speed_multiplier}"
    
    try:
        async with websockets.connect(uri) as websocket:
            print(f"Connected to WebSocket server (Speed: {speed_multiplier}x)")
            
            # Continuously receive messages
            while True:
                try:
                    # Receive and parse the JSON message
                    message = await websocket.recv()
                    data = json.loads(message)
                    
                    # Extract and format the timestamp for display
                    timestamp = datetime.fromisoformat(data['timestamp'].replace('Z', '+00:00'))
                    
                    # Print a formatted summary of the received data
                    print(f"\nTimestamp: {timestamp}")
                    print(f"Manual Time Difference: {data['manual_timediff']}")
                    print(f"Number of buses in this batch: {len(data['data'])}")
                    
                    # Print details of the first bus as a sample
                    if data['data']:
                        first_bus = data['data'][0]
                        print("\nSample bus data:")
                        print(f"Bus ID: {first_bus.get('bus_id')}")
                        print(f"Location: ({first_bus.get('latitude')}, {first_bus.get('longitude')})")
                        
                    print(data['data'])
                except websockets.exceptions.ConnectionClosed:
                    print("Connection closed by server")
                    break
                    
    except Exception as e:
        print(f"Error: {str(e)}")

# Since Jupyter requires special handling for asyncio, we'll use this helper function
async def run_test(speed_multiplier: float = 2.0):
    await connect_to_websocket(speed_multiplier)

# In Jupyter, you'll need to run this cell to start the connection
# Change the speed_multiplier value to adjust simulation speed
await run_test(speed_multiplier=20)  # Run at 2x speed
# Out:
# Connected to WebSocket server (Speed: 20x)
#
# Timestamp: 2025-01-12 09:00:00
# Manual Time Difference: 0
# Number of buses in this batch: 2
#
# Sample bus data:
# Bus ID: 636c2502-8780-46b5-8c5c-abfa8ae8a185
# Location: (49.266003, -123.247825)
#
# Timestamp: 2025-01-12 09:01:10.348644
# Manual Time Difference: 70
# Number of buses in this batch: 1
#
# Sample bus data:
# Bus ID: 636c2502-8780-46b5-8c5c-abfa8ae8a185
# Location: (49.2661378655, -123.2468828487)
#
# Timestamp: 2025-01-12 09:01:46.294054
# Manual Time Difference: 106
# Number of buses in this batch: 1
#
# Sample bus data:
# Bus ID: bc1d2f55-b4f7-4dfc-bddd-9e3127e8a9de
# Location: (49.2828118151, -123.1094909496)
#
# Timestamp: 2025-01-12 09:02:34.354170
# Manual Time Difference: 154
# Number of buses in this batch: 1
#
# Sample bus data:
# Bus ID: 636c2502-8780-46b5-8c5c-abfa8ae8a185
# Location: (49.266322521, -123.245605521)
#
# Timestamp: 2025-01-12 09:02:56.014721
# Manual Time Difference: 176
# Number of buses in this batch: 1
#
# Sample bus data:
# Bus ID: bc1d2f55-b4f7-4dfc-bddd-9e3127e8a9de
# Location: (49.2838130924, -123.1095687647)
#
# Timestamp: 2025-01-12 09:03:46.019107
# Manual Time Difference: 226
# Number of buses in this batch: 1
#
# Sample bus data:
# Bus ID: 636c2502-8780-46b5-8c5c-abfa8ae8a185
# Location: (49.2663511345, -123.2454074958)
#
# Timestamp: 2025-01-12 09:04:16.019107
# Manual Time Difference: 256
# Number of buses in this batch: 1
#
# Sample bus data:
# Bus ID: 636c2502-8780-46b5-8c5c-abfa8ae8a185
# Location: (49.2663635798, -123.2453175546)
#
# Timestamp: 2025-01-12 09:04:33.686872
# Manual Time Difference: 273
# Number of buses in this batch: 1
#
# Sample bus data:
# Bus ID: bc1d2f55-b4f7-4dfc-bddd-9e3127e8a9de
# Location: (49.2845677311, -123.1107075042)
#
# Timestamp: 2025-01-12 09:05:49.923466
# Manual Time Difference: 349
# Number of buses in this batch: 1
#
# Sample bus data:
# Bus ID: bc1d2f55-b4f7-4dfc-bddd-9e3127e8a9de
# Location: (49.2847339664, -123.1109572437)
#
# Timestamp: 2025-01-12 09:06:05.717172
# Manual Time Difference: 365
# Number of buses in this batch: 1
#
# Sample bus data:
# Bus ID: 636c2502-8780-46b5-8c5c-abfa8ae8a185
# Location: (49.2664906891, -123.2443928487)
#
# Timestamp: 2025-01-12 09:06:53.512024
# Manual Time Difference: 413
# Number of buses in this batch: 1
#
# Sample bus data:
# Bus ID: bc1d2f55-b4f7-4dfc-bddd-9e3127e8a9de
# Location: (49.2851260336, -123.1121554286)
#
# Timestamp: 2025-01-12 09:07:52.292024
# Manual Time Difference: 472
# Number of buses in this batch: 1
#
# Sample bus data:
# Bus ID: 636c2502-8780-46b5-8c5c-abfa8ae8a185
# Location: (49.2666871345, -123.2430821261)
#
# Timestamp: 2025-01-12 09:08:01.572480
# Manual Time Difference: 481
# Number of buses in this batch: 1
#
# Sample bus data:
# Bus ID: bc1d2f55-b4f7-4dfc-bddd-9e3127e8a9de
# Location: (49.2843012857, -123.1134039496)
#
# Timestamp: 2025-01-12 09:09:05.604034
# Manual Time Difference: 545
# Number of buses in this batch: 1
#
# Sample bus data:
# Bus ID: bc1d2f55-b4f7-4dfc-bddd-9e3127e8a9de
# Location: (49.2831666471, -123.1151196471)
#
# Timestamp: 2025-01-12 09:09:21.814091
# Manual Time Difference: 561
# Number of buses in this batch: 1
#
# Sample bus data:
# Bus ID: 636c2502-8780-46b5-8c5c-abfa8ae8a185
# Location: (49.2668838235, -123.2414697059)
#
# Timestamp: 2025-01-12 09:10:27.839396
# Manual Time Difference: 627
# Number of buses in this batch: 1
#
# Sample bus data:
# Bus ID: bc1d2f55-b4f7-4dfc-bddd-9e3127e8a9de
# Location: (49.2826026555, -123.1159692269)
#
# Timestamp: 2025-01-12 09:10:48.960652
# Manual Time Difference: 648
# Number of buses in this batch: 1
#
# Sample bus data:
# Bus ID: 636c2502-8780-46b5-8c5c-abfa8ae8a185
# Location: (49.2669002941, -123.2402587647)
#
# Timestamp: 2025-01-12 09:12:08.173452
# Manual Time Difference: 728
# Number of buses in this batch: 1
#
# Sample bus data:
# Bus ID: 636c2502-8780-46b5-8c5c-abfa8ae8a185
# Location: (49.2668493445, -123.2395153445)
#
# Timestamp: 2025-01-12 09:12:27.356903
# Manual Time Difference: 747
# Number of buses in this batch: 1
#
# Sample bus data:
# Bus ID: bc1d2f55-b4f7-4dfc-bddd-9e3127e8a9de
# Location: (49.2814449748, -123.1177095882)
#
# Timestamp: 2025-01-12 09:13:59.836932
# Manual Time Difference: 839
# Number of buses in this batch: 1
#
# Sample bus data:
# Bus ID: 636c2502-8780-46b5-8c5c-abfa8ae8a185
# Location: (49.266806437, -123.2392110588)
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[1], line 49
#      45     await connect_to_websocket(speed_multiplier)
#      47 # In Jupyter, you'll need to run this cell to start the connection
#      48 # Change the speed_multiplier value to adjust simulation speed
# ---> 49 await run_test(speed_multiplier=20)
#
# Cell In[1], line 45, in run_test(speed_multiplier)
#      44 async def run_test(speed_multiplier: float = 2.0):
# ---> 45     await connect_to_websocket(speed_multiplier)
#
# Cell In[1], line 18, in connect_to_websocket(speed_multiplier)
#      15 while True:
#      16     try:
#      17         # Receive and parse the JSON message
# ---> 18         message = await websocket.recv()
#      19         data = json.loads(message)
#      21         # Extract and format the timestamp for display
#
# File ~/miniforge3/lib/python3.11/site-packages/websockets/legacy/protocol.py:546, in WebSocketCommonProtocol.recv(self)
#     542 self._pop_message_waiter = pop_message_waiter
#     543 try:
#     544     # If asyncio.wait() is canceled, it doesn't cancel
#     545     # pop_message_waiter and self.transfer_data_task.
# --> 546     await asyncio.wait(
#     547         [pop_message_waiter, self.transfer_data_task],
#     548         return_when=asyncio.FIRST_COMPLETED,
#     549     )
#     550 finally:
#     551     self._pop_message_waiter = None
#
# File ~/miniforge3/lib/python3.11/asyncio/tasks.py:428, in wait(fs, timeout, return_when)
#     425     raise TypeError("Passing coroutines is forbidden, use tasks explicitly.")
#     427 loop = events.get_running_loop()
# --> 428 return await _wait(fs, timeout, return_when, loop)
#
# File ~/miniforge3/lib/python3.11/asyncio/tasks.py:535, in _wait(fs, timeout, return_when, loop)
#     532     f.add_done_callback(_on_completion)
#     534 try:
# --> 535     await waiter
#     536 finally:
#     537     if timeout_handle is not None:
#
# CancelledError:
